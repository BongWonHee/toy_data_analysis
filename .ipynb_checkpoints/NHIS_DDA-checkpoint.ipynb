# %%
import pymongo as mg

# %%
client = mg.MongoClient(host='mongodb://localhost:27017/')

# %%
database=client['db_NHIS']
database
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_NHIS')

# %%
collection = database['Join_NSC2_BND_M20']

# %%
collection.find({})

# %%
cursor = collection.find({})

# %%
list_join = list(cursor)

# %%
import pandas as pd

# %%
pd.DataFrame(list_join)
# Out:
#                              _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1  \
# 0       64e6bd24960e3ecc434e21b1   294364   1921LE    200707.0  T08-T14
# 1       64e6bd24960e3ecc434e21b2   294364   1921LE    200707.0  T08-T14
# 2       64e6bd24960e3ecc434e21b3   294364   1921LE    200707.0  T08-T14
# 3       64e6bd24960e3ecc434e21b4   294364   1921LE    200707.0  T08-T14
# 4       64e6bd24960e3ecc434e21b5   294364   1921LE    200707.0  T08-T14
# ...                          ...      ...      ...         ...      ...
# 137158  64e6bd45960e3ecc4350399a  3000758     2015         NaN      NaN
# 137159  64e6bd45960e3ecc4350399b  3000758     2015         NaN      NaN
# 137160  64e6bd45960e3ecc4350399c  3000758     2015         NaN      NaN
# 137161  64e6bd45960e3ecc4350399d  3000758     2015         NaN      NaN
# 137162  64e6bd45960e3ecc4350399e  3000758     2015         NaN      NaN
#
#            COD2         RN_KEY  RN_INST  MDCARE_STRT_DT  FORM_CD  ...  \
# ...

# %%
df_NBM = pd.DataFrame(list_join)

# %%
df_NBM
# Out:
#                              _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1  \
# 0       64e6bd24960e3ecc434e21b1   294364   1921LE    200707.0  T08-T14
# 1       64e6bd24960e3ecc434e21b2   294364   1921LE    200707.0  T08-T14
# 2       64e6bd24960e3ecc434e21b3   294364   1921LE    200707.0  T08-T14
# 3       64e6bd24960e3ecc434e21b4   294364   1921LE    200707.0  T08-T14
# 4       64e6bd24960e3ecc434e21b5   294364   1921LE    200707.0  T08-T14
# ...                          ...      ...      ...         ...      ...
# 137158  64e6bd45960e3ecc4350399a  3000758     2015         NaN      NaN
# 137159  64e6bd45960e3ecc4350399b  3000758     2015         NaN      NaN
# 137160  64e6bd45960e3ecc4350399c  3000758     2015         NaN      NaN
# 137161  64e6bd45960e3ecc4350399d  3000758     2015         NaN      NaN
# 137162  64e6bd45960e3ecc4350399e  3000758     2015         NaN      NaN
#
#            COD2         RN_KEY  RN_INST  MDCARE_STRT_DT  FORM_CD  ...  \
# ...

# %%
df_NBM.to_csv('./join_BND_M20.csv')

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('font', family='Malgun Gothic')
import seaborn as sns

# %%
df_NBM20 = pd.read_csv('./join_BND_M20.csv')
# Out:
# C:\Users\05-27\AppData\Local\Temp\ipykernel_3532\1786905413.py:1: DtypeWarning: Columns (3,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_NBM20 = pd.read_csv('./join_BND_M20.csv')

# %%
df_NBM20
# Out:
#         Unnamed: 0                       _id  RN_INDI BTH_YYYY  DTH_YYYYMM  \
# 0                0  64e6bd24960e3ecc434e21b1   294364   1921LE    200707.0
# 1                1  64e6bd24960e3ecc434e21b2   294364   1921LE    200707.0
# 2                2  64e6bd24960e3ecc434e21b3   294364   1921LE    200707.0
# 3                3  64e6bd24960e3ecc434e21b4   294364   1921LE    200707.0
# 4                4  64e6bd24960e3ecc434e21b5   294364   1921LE    200707.0
# ...            ...                       ...      ...      ...         ...
# 137158      137158  64e6bd45960e3ecc4350399a  3000758     2015         NaN
# 137159      137159  64e6bd45960e3ecc4350399b  3000758     2015         NaN
# 137160      137160  64e6bd45960e3ecc4350399c  3000758     2015         NaN
# 137161      137161  64e6bd45960e3ecc4350399d  3000758     2015         NaN
# 137162      137162  64e6bd45960e3ecc4350399e  3000758     2015         NaN
#
# ...

# %%
df_NBM20_simple=df_NBM20[['SICK_SYM1','OPRTN_YN','BTH_YYYY','VSHSP_DD_CNT','EDC_SBA','MDCARE_DD_CNT','EDC_INSUR_BRDN_AMT']]

# %%
df_NBM20_simple.to_csv('./NBM20_simple.csv')

# %%
df_NBMQ = pd.read_csv('./NBM20_simple.csv')
# Out:
# C:\Users\05-27\AppData\Local\Temp\ipykernel_3532\1177914074.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_NBMQ = pd.read_csv('./NBM20_simple.csv')

# %%
df_NBMQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137163 entries, 0 to 137162
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          137163 non-null  int64
#  1   SICK_SYM1           137163 non-null  object
#  2   OPRTN_YN            137163 non-null  int64
#  3   BTH_YYYY            137163 non-null  object
#  4   VSHSP_DD_CNT        137163 non-null  int64
#  5   EDC_SBA             137163 non-null  int64
#  6   MDCARE_DD_CNT       137163 non-null  int64
#  7   EDC_INSUR_BRDN_AMT  137163 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 8.4+ MB

# %%
df_NBMQ['SICK_SYM1']
# Out:
# 0         L028
# 1         J030
# 2         J030
# 3         K291
# 4         M545
#           ...
# 137158    J209
# 137159    J209
# 137160    J209
# 137161    J209
# 137162     J00
# Name: SICK_SYM1, Length: 137163, dtype: object

# %%
df_NBMQ_i10 = df_NBMQ[df_NBMQ['SICK_SYM1'] == 'I10']

# %%
df_NBMQ_i10
# Out:
#         Unnamed: 0 SICK_SYM1  OPRTN_YN BTH_YYYY  VSHSP_DD_CNT  EDC_SBA  \
# 190            190       I10         0   1921LE             1     3000
# 195            195       I10         0   1921LE             2     6000
# 197            197       I10         0   1921LE             1     3000
# 284            284       I10         0   1921LE             1     4200
# 769            769       I10         0   1921LE             1     1500
# ...            ...       ...       ...      ...           ...      ...
# 124484      124484       I10         0     2005             1     3000
# 124485      124485       I10         0     2005             1     3000
# 124486      124486       I10         0     2005             1     3000
# 124495      124495       I10         0     2005             1     3000
# 124590      124590       I10         0     2005             1     1500
#
#         MDCARE_DD_CNT  EDC_INSUR_BRDN_AMT
# 190                 1                4570
# ...

# %%
df_NBMQ_i10.isnull().sum()
# Out:
# Unnamed: 0            0
# SICK_SYM1             0
# OPRTN_YN              0
# BTH_YYYY              0
# VSHSP_DD_CNT          0
# EDC_SBA               0
# MDCARE_DD_CNT         0
# EDC_INSUR_BRDN_AMT    0
# dtype: int64

# %%
df_NBMQ_i10.to_csv('./NBMQ_i10.csv')
